# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# -   Download a webpage using requests module
# -   Scrape all links from a web page
# -   Scrape all image urls from a web page
# -   Scrape data from html tables

# %% [markdown]
# ## Scrape [www.ibm.com](http://www.ibm.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
data = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %%
soup = BeautifulSoup(data, 'html5lib')

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.ibm.com/jp/ja
# https://www.ibm.com/sitemap/jp/ja
# https://jp.newsroom.ibm.com/2021-04-27-AI-utilization-human-resource-development-program-virtual-learning-version?lnk=jphpv18l1&lnk2=learn
# https://www.ibm.com/events/think?global=true&lnk=jphpv18f1&lnk2=learn
# https://www.ibm.com/blogs/systems/jp-ja/ibm-z15-wins-if-design-award-2021/?lnk=jphpv18f2&lnk2=learn
# https://www.ibm.com/blogs/think/jp-ja/accelerated-discovery-sustainable-pags/?lnk=jphpv18f3&lnk2=learn
# https://www.ibm.com/jp-ja/events/x-online?lnk=jphpv18f4&lnk2=learn
# /jp-ja/products/trials?lnk=STW_JP_HPT_C1_TL&lnk2=trial_THP&psrc=none&pexp=def
# /jp-ja/products/cloud-pak-for-data?lnk=STW_JP_HPT_T1_BTN&lnk2=trial_CloudPakData&psrc=none&pexp=def
# /jp-ja/cloud/db2-on-cloud?lnk=STW_JP_HPT_T2_BTN&lnk2=trial_Db2Cloud&psrc=none&pexp=def
# /jp-ja/products/storage-suite-for-ibm-cloud-paks?lnk=STW_JP_HPT_T3_BTN&lnk2=trial_SSCP&psrc=none&pexp=def
# /jp-ja/cloud/hybrid?lnk=hpv18pt14
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /jp-ja/watson?lnk=ushpv18pt17
# /jp-ja/garage?lnk=hpv18pt13
# /jp-ja/blockchain?lnk=hpv18pt4
# https://www.ibm.com/jp-ja/analytics?lnk=hpv18pt1
# /jp-ja/security?lnk=hpv18pt9
# /jp-ja/quantum-computing?lnk=hpv18pt16
# /jp-ja/financing?lnk=hpv18pt3
# https://www.ibm.com/services/jp-ja/studies/thoughtleadership/?lnk=hpv18pt12
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18ct16
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18ct19
# https://www.ibm.com/demos/?lc=ja&lnk=hpv18ct12
# https://developer.ibm.com/?lnk=hpv18ct9
# https://www.ibm.com/support/knowledgecenter/ja/?lnk=hpv18ct14
# https://www.redbooks.ibm.com/?lnk=ushpv18ct10
# https://www.ibm.com/mysupport/s/?language=ja&lnk=hpv18ct11
# https://www.ibm.com/training/?lnk=hpv18ct15
# /jp-ja/cloud/hybrid?lnk=hpv18ct20
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /jp-ja/cloud/redhat?lnk=hpv18ct13
# /jp-ja/watson?lnk=hpv18ct3
# /jp-ja/quantum-computing?lnk=hpv18ct18
# /jp-ja/cloud/kubernetes-service?lnk=hpv18ct8
# /jp-ja/products/spss-statistics?lnk=ushpv18ct7
# /jp-ja/products/category/technology/blockchain?lnk=hpv18ct1
# https://www.ibm.com/jp-ja/employment/?lnk=hpv18ct2
# /jp-ja/quantum-computing?lnk=hpv18cs1
# https://www.ibm.com/industries/jp/ja/case-studies/?lnk=hpv18cs2
# #

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))

# %%
for link in soup.find_all('img'):
    print(link.get('src'))
# Out:
# //1.cms.s81c.com/sites/default/files/2021-04-26/this-week-at-ibm-think-20210426-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2021-04-23/this-week-at-ibm-award-20210426-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2021-04-23/this-week-at-ibm-accelerated-discovery-20210426-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2021-04-16/this-week-at-ibm-xonline-20210419-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2021-02-17/cloud-pak-for-data-trial.png
# //1.cms.s81c.com/sites/default/files/2021-04-08/Db2-on-Cloud.png
# //1.cms.s81c.com/sites/default/files/2021-04-08/storage-suite-for-cloud-pak-trial.png

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
data = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
soup = BeautifulSoup(data,'html5lib')

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
table = soup.find('table')

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %%
for row in table.find_all('tr'):
    cols = row.find_all('td')
    color_name = cols[2].getText()
    color_code = cols[3].getText()
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
